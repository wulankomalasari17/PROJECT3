# %%
import pandas as pd

last_names = ['Connor', 'Connor', 'Reese']
first_names = ['Sarah', 'John', 'Kyle']
df = pd.DataFrame({
  'first_name': first_names,
  'last_name': last_names,
})

url = "https://raw.githubusercontent.com/FillahAlamsyah/Machine-Learning-Prediksi-Posisi-Pada-Gerak-Parabola/main/DatabaseGerakParabola.txt"
database = pd.read_csv (url, sep=',')
'''pd.read_csv('data.csv')'''
print(database.columns)
print(database.describe())
print(database.head())
print(database.tail())
# Out:
# Index(['t ', ' Posisix ', ' Posisiy'], dtype='object')
#              t    Posisix     Posisiy
# count  25.00000  25.000000  25.000000
# mean    1.20000   8.485600   8.881200
# std     0.73598   5.204229   4.158264
# min     0.00000   0.000000  -1.250000
# 25%     0.60000   4.240000   6.850000
# 50%     1.20000   8.490000  10.660000
# 75%     1.80000  12.730000  12.040000
# max     2.40000  16.970000  12.550000
#     t    Posisix    Posisiy
# 0  0.0       0.00     10.00
# 1  0.1       0.71     10.66
# 2  0.2       1.41     11.22
# 3  0.3       2.12     11.68
# 4  0.4       2.83     12.04
#      t    Posisix    Posisiy
# 20  2.0      14.14      4.54
# 21  2.1      14.85      3.24
# 22  2.2      15.56      1.84
# 23  2.3      16.26      0.34
# 24  2.4      16.97     -1.25

# %%
import numpy as np
x = [i for i in range(5,12)]
y1 = np.tan(x)
y2 = np.cos(x)


print(x,y1,y2)
# Out:
# [5, 6, 7, 8, 9, 10, 11] [  -3.38051501   -0.29100619    0.87144798   -6.79971146   -0.45231566
#     0.64836083 -225.95084645] [ 0.28366219  0.96017029  0.75390225 -0.14550003 -0.91113026 -0.83907153
#   0.0044257 ]

# %%
dataframe = pd.DataFrame({
    'x': x,
    'y1': y1,
    'y2': y2,

                             })
dataframe['z1'] = np.tan(x)
dataframe['z2'] = np.cos(x)

dataframe
# Out:
#     x          y1        y2          z1        z2
# 0   5   -3.380515  0.283662   -3.380515  0.283662
# 1   6   -0.291006  0.960170   -0.291006  0.960170
# 2   7    0.871448  0.753902    0.871448  0.753902
# 3   8   -6.799711 -0.145500   -6.799711 -0.145500
# 4   9   -0.452316 -0.911130   -0.452316 -0.911130
# 5  10    0.648361 -0.839072    0.648361 -0.839072
# 6  11 -225.950846  0.004426 -225.950846  0.004426
